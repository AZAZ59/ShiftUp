# %%
import numpy as np
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %pylab inline

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10
import pandas as pd
import seaborn as sns
import sqlite3 as sqlite
import matplotlib.pyplot as plt
import datetime
from sqlalchemy import create_engine

sns.set(rc=rcParams)
sns.set_style("darkgrid", {
    "axes.facecolor": "#282828",
    "axes.edgecolor":"#282828",
    "grid.color":"#298F4A",
    "xtick.color":"1",
    "ytick.color":"1",
    "text.color":"1",
    "axes.labelcolor":"1",
    "figure.facecolor":"#282828"
})
sns.set_palette(sns.color_palette("BrBG", 7))
# sns.reset_defaults()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%time
engine = create_engine('postgresql://postgres:123123@localhost:5432/postgres')
data=pd.read_sql('select * from online',engine)
data['time']=pd.to_datetime(data['time'])
# data.time=data.time.astype(int)
# Out:
# CPU times: user 1.89 s, sys: 199 ms, total: 2.09 s
# Wall time: 2.7 s

# %%
pd.io.sql.SQLDatabase??

# %%
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354956 entries, 0 to 354955
# Data columns (total 8 columns):
# first_name       354956 non-null object
# hidden           114910 non-null float64
# last_name        354956 non-null object
# online           354956 non-null int64
# online_app       47217 non-null object
# online_mobile    50285 non-null float64
# uid              354956 non-null int64
# time             354956 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 21.7+ MB
# None
#   first_name  hidden   last_name  online online_app  online_mobile        uid  \
# 0  Екатерина     NaN  Эдуардовна       0       None            NaN  295221459
# 1     Доктор     NaN    Сотников       1    3140623            1.0  295237226
# 2      Danya     1.0     Nikitin       0       None            NaN  296917953
# 3    Алексей     NaN    Игоревич       1       None            NaN  297127521
# ...

# %%
uids=data.groupby('uid')
maxOnline=uids.online.sum().max()
data=uids.filter(lambda x:x.online.sum() > 10 and x.online
                 .sum()<maxOnline)
data['time']=pd.to_datetime(data['time'])

print(data.info())
print(data.describe())
print('uniq ids:{}'.format(len(pd.unique(data['uid'].values))))
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 231447 entries, 0 to 353947
# Data columns (total 8 columns):
# first_name       231447 non-null object
# hidden           97682 non-null float64
# last_name        231447 non-null object
# online           231447 non-null int64
# online_app       46589 non-null object
# online_mobile    49597 non-null float64
# uid              231447 non-null int64
# time             231447 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 15.9+ MB
# None
#         hidden         online  online_mobile           uid
# count  97682.0  231447.000000        49597.0  2.314470e+05
# mean       1.0       0.295364            1.0  1.314708e+08
# std        0.0       0.456207            0.0  1.124895e+08
# min        1.0       0.000000            1.0  1.047000e+03
# 25%        1.0       0.000000            1.0  2.371678e+07
# 50%        1.0       0.000000            1.0  1.181638e+08
# ...

# %%
# data[data.uid==269339188]['online'].plot('time')
cols=['online','time']
d=data[data.uid==2211885]
# sns.distplot(d['time'])
sns.pairplot(d[cols])

# %%
inTime.resample('1H').index.strftime("%Y-%m-%d : %H")
# Out:
# array(['2017-03-11 : 14', '2017-03-11 : 15', '2017-03-11 : 16',
#        '2017-03-11 : 17', '2017-03-11 : 18', '2017-03-11 : 19',
#        '2017-03-11 : 20', '2017-03-11 : 21', '2017-03-11 : 22',
#        '2017-03-11 : 23', '2017-03-12 : 00', '2017-03-12 : 01',
#        '2017-03-12 : 02', '2017-03-12 : 03', '2017-03-12 : 04',
#        '2017-03-12 : 05', '2017-03-12 : 06', '2017-03-12 : 07',
#        '2017-03-12 : 08', '2017-03-12 : 09', '2017-03-12 : 10',
#        '2017-03-12 : 11', '2017-03-12 : 12', '2017-03-12 : 13',
#        '2017-03-12 : 14', '2017-03-12 : 15', '2017-03-12 : 16',
#        '2017-03-12 : 17', '2017-03-12 : 18', '2017-03-12 : 19',
#        '2017-03-12 : 20', '2017-03-12 : 21', '2017-03-12 : 22',
#        '2017-03-12 : 23', '2017-03-13 : 00', '2017-03-13 : 01',
#        '2017-03-13 : 02', '2017-03-13 : 03', '2017-03-13 : 04',
#        '2017-03-13 : 05', '2017-03-13 : 06', '2017-03-13 : 07',
#        '2017-03-13 : 08', '2017-03-13 : 09', '2017-03-13 : 10',
# ...

# %%
pd.io.sql.SQLTable??

# %%
inTime=data.groupby('time').online.sum()
# inTime[['online','time']].groupby('time').online.sum().plot()
inTime.describe() 
inTime=pd.DataFrame(inTime)

# inTime.plot()
# inTime=inTime.reset_index()
# inTime.resample('10T').mean().dropnHa().plot(
#     xticks=inTime.resample('10T').index.strftime("%Y-%m-%d : %H"),
#     figsize=(40,30)
# )

ax = inTime.plot(
#     fontsize=30,
#     figsize=(80,40),
#     linewidth = 5
)
ax.set_xticklabels(inTime.resample('6H').index.strftime("%Y-%m-%d : %H"));
# sns.axes_style()

# %%
sns.distplot(inTime)

# %%
sns.distplot(list(filter(lambda x:x<inTime.mean()+3*inTime.std() and x>inTime.mean()-3*inTime.std() ,inTime)));

# %%
data[pd.notnull(data.online_mobile)]
# sns.distplot(
#     data[data.online_mobile == 1].groupby('time').online.sum()
# )
# Out:
#            first_name  hidden            last_name  online online_app  \
# 30             Рафаэл     NaN           Сулейманов       1    3140623
# 33               Анна     1.0            Болотнова       1    3140623
# 46               Анна     1.0                 Кара       1    2274003
# 47              Ксюша     1.0               Дёмина       1    2274003
# 49             Андрей     NaN             Желтышев       1    2685278
# 67               Женя     NaN                 Женя       1    3140623
# 68          Александр     NaN                Щипак       1    2274003
# 70          Анастасия     1.0              Зуйкова       1    2685278
# 89              Ирина     1.0                Сокол       1    3140623
# 91           Серафима     1.0            Самойлова       1    3140623
# 99              Алена     NaN              Шемберг       1    2274003
# 117           Алексей     NaN             Игоревич       1    3140623
# ...

# %%
# data=data.set_index('time')
d2=data[data.online_mobile == 1].set_index('time').online
d2
# d2.resample("10T").mean().fillna(method='ffill').plot()

# pd.DataFrame.asfreq?
# x=d2.resample("10T", fill_method='ffill')
# x.plot()
# x.index

# print(x.iloc[:15])
# d2.iloc[:10]
# Out:
# time
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# 2017-03-11 14:43:02.867167    1
# ...

# %%
data=pd.read_csv('friends.csv')
print(data.info())
a=set(data.u0.values)
b=set(data.u1.values)
print("+++++++")
print(len(data.u0.unique()))
print(len(data.u1.unique()))
print("+"*20)
print("from:",len(a))
print("to  :",len(b))
a.update(b)
print("sum :",len(a))
asd=list(a)
asd.sort()
nodes=pd.Series(asd)
nodes.to_csv('nodes.csv',index=False)
# pd.DataFrame(nodes).info()
# nodes.sort_values("0")
# nodes.sort_values("uid")



# data=data.sort('u0')
# data=data.drop_duplicates()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 